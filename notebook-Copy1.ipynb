# %%
import warnings # ignore warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')

from wordcloud import WordCloud

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.tokenize import regexp_tokenize, word_tokenize, RegexpTokenizer

from sklearn import preprocessing
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, RepeatedStratifiedKFold, cross_val_score, train_test_split
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score, classification_report, plot_confusion_matrix
from sklearn.dummy import DummyClassifier
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
# Import the data
critics = pd.read_csv('./data/rotten_tomatoes_critic_reviews_50k.csv')
critics
# Out:
#               rotten_tomatoes_link      critic_name  top_critic  \
# 0                        m/0814255  Andrew L. Urban       False
# 1                        m/0814255    Louise Keller       False
# 2                        m/0814255              NaN       False
# 3                        m/0814255     Ben McEachen       False
# 4                        m/0814255      Ethan Alter        True
# ...                            ...              ...         ...
# 49995  m/1110242-collateral_damage     Chris Hewitt       False
# 49996  m/1110242-collateral_damage      Nick Carter       False
# 49997  m/1110242-collateral_damage      Gary Dowell        True
# 49998  m/1110242-collateral_damage      Walter Chaw       False
# 49999  m/1110242-collateral_damage   Sean O'Connell       False
#
#                    publisher_name review_type review_score review_date  \
# 0                  Urban Cinefile       Fresh          NaN  2010-02-06
# 1                  Urban Cinefile       Fresh          NaN  2010-02-06
# 2             FILMINK (Australia)       Fresh          NaN  2010-02-09
# 3         Sunday Mail (Australia)       Fresh        3.5/5  2010-02-09
# 4              Hollywood Reporter      Rotten          NaN  2010-02-10
# ...                           ...         ...          ...         ...
# 49995      St. Paul Pioneer Press      Rotten          NaN  2002-02-07
# 49996  Milwaukee Journal Sentinel      Rotten          NaN  2002-02-07
# 49997         Dallas Morning News      Rotten          NaN  2002-02-07
# 49998          Film Freak Central      Rotten          0/4  2002-02-07
# 49999            Eclipse Magazine      Rotten          NaN  2002-02-07
#
#                                           review_content
# 0      A fantasy adventure that fuses Greek mythology...
# 1      Uma Thurman as Medusa, the gorgon with a coiff...
# 2      With a top-notch cast and dazzling special eff...
# 3      Whether audiences will get behind The Lightnin...
# 4      What's really lacking in The Lightning Thief i...
# ...                                                  ...
# 49995  The smarter an Arnold Schwarzenegger movie tri...
# 49996                                A relative letdown.
# 49997  The movie straddles the fence between escapism...
# 49998  Enough similarities to Gymkata and Howie Long'...
# 49999  Age, and a steady diet of Republican conservat...
#
# [50000 rows x 8 columns]

# %%
# Import the data
movies = pd.read_csv('./data/rotten_tomatoes_movies.csv')
movies
# Out:
#                         rotten_tomatoes_link  \
# 0                                  m/0814255
# 1                                  m/0878835
# 2                                       m/10
# 3                     m/1000013-12_angry_men
# 4      m/1000079-20000_leagues_under_the_sea
# ...                                      ...
# 17707                            m/zoot_suit
# 17708                             m/zootopia
# 17709                      m/zorba_the_greek
# 17710                                 m/zulu
# 17711                            m/zulu_dawn
#
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 17707                                          Zoot Suit
# 17708                                           Zootopia
# 17709                                    Zorba the Greek
# 17710                                               Zulu
# 17711                                          Zulu Dawn
#
#                                               movie_info  \
# 0      Always trouble-prone, the life of teenager Per...
# 1      Kate (Catherine Keener) and her husband Alex (...
# 2      A successful, middle-aged Hollywood songwriter...
# 3      Following the closing arguments in a murder tr...
# 4      In 1866, Professor Pierre M. Aronnax (Paul Luk...
# ...                                                  ...
# 17707  Mexican-American gangster Henry Reyna (Daniel ...
# 17708  From the largest elephant to the smallest shre...
# 17709  Traveling to inspect an abandoned mine his fat...
# 17710  In 1879, the Zulu nation hands colonial Britis...
# 17711  Sir Henry Bartle Frere's (John Mills) vastly o...
#
#                                        critics_consensus content_rating  \
# 0      Though it may seem like just another Harry Pot...             PG
# 1      Nicole Holofcener's newest might seem slight i...              R
# 2      Blake Edwards' bawdy comedy may not score a pe...              R
# 3      Sidney Lumet's feature debut is a superbly wri...             NR
# 4      One of Disney's finest live-action adventures,...              G
# ...                                                  ...            ...
# 17707                                                NaN              R
# 17708  The brilliantly well-rounded Zootopia offers a...             PG
# 17709                                                NaN             NR
# 17710  Zulu patiently establishes a cast of colorful ...             PG
# 17711                                                NaN             PG
#
#                                                   genres  \
# 0      Action & Adventure, Comedy, Drama, Science Fic...
# 1                                                 Comedy
# 2                                        Comedy, Romance
# 3                                        Classics, Drama
# 4               Action & Adventure, Drama, Kids & Family
# ...                                                  ...
# 17707                   Drama, Musical & Performing Arts
# 17708              Action & Adventure, Animation, Comedy
# 17709  Action & Adventure, Art House & International,...
# 17710                                    Classics, Drama
# 17711  Action & Adventure, Art House & International,...
#
#                                   directors  \
# 0                            Chris Columbus
# 1                         Nicole Holofcener
# 2                             Blake Edwards
# 3                              Sidney Lumet
# 4                         Richard Fleischer
# ...                                     ...
# 17707                           Luis Valdez
# 17708  Byron Howard, Rich Moore, Jared Bush
# 17709                                   NaN
# 17710           Cy Endfield, Cyril Endfield
# 17711                        Douglas Hickox
#
#                                           authors  \
# 0      Craig Titley, Chris Columbus, Rick Riordan
# 1                               Nicole Holofcener
# 2                                   Blake Edwards
# 3                                   Reginald Rose
# 4                                     Earl Felton
# ...                                           ...
# 17707                                 Luis Valdez
# 17708                   Jared Bush, Phil Johnston
# 17709                                         NaN
# 17710                   Cy Endfield, John Prebble
# 17711                 Cy Endfield, Anthony Storey
#
#                                                   actors  \
# 0      Logan Lerman, Brandon T. Jackson, Alexandra Da...
# 1      Catherine Keener, Amanda Peet, Oliver Platt, R...
# 2      Dudley Moore, Bo Derek, Julie Andrews, Robert ...
# 3      Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
# 4      James Mason, Kirk Douglas, Paul Lukas, Peter L...
# ...                                                  ...
# 17707  Daniel Valdez, Edward James Olmos, Charles Aid...
# 17708  J.K. Simmons, Kristen Bell, Octavia Spencer, A...
# 17709  Anthony Quinn, Alan Bates, Irene Papas, Lila K...
# 17710  Stanley Baker, Jack Hawkins, Ulla Jacobsson, J...
# 17711  Burt Lancaster, Peter O'Toole, Simon Ward, Joh...
#
#       original_release_date  ...             production_company  \
# 0                2010-02-12  ...               20th Century Fox
# 1                2010-04-30  ...         Sony Pictures Classics
# 2                1979-10-05  ...                    Waner Bros.
# 3                1957-04-13  ...           Criterion Collection
# 4                1954-01-01  ...                         Disney
# ...                     ...  ...                            ...
# 17707            1981-10-02  ...       MCA Universal Home Video
# 17708            2016-03-04  ...  Walt Disney Animation Studios
# 17709            1964-12-17  ...                            Fox
# 17710            1964-06-17  ...             Paramount Pictures
# 17711            1979-12-14  ...            Tango Entertainment
#
#        tomatometer_status tomatometer_rating tomatometer_count  \
# 0                  Rotten               49.0             149.0
# 1         Certified-Fresh               87.0             142.0
# 2                   Fresh               67.0              24.0
# 3         Certified-Fresh              100.0              54.0
# 4                   Fresh               89.0              27.0
# ...                   ...                ...               ...
# 17707              Rotten               56.0               9.0
# 17708     Certified-Fresh               98.0             291.0
# 17709               Fresh               80.0              10.0
# 17710               Fresh               96.0              23.0
# 17711              Rotten               50.0               8.0
#
#        audience_status  audience_rating audience_count  \
# 0              Spilled             53.0       254421.0
# 1              Upright             64.0        11574.0
# 2              Spilled             53.0        14684.0
# 3              Upright             97.0       105386.0
# 4              Upright             74.0        68918.0
# ...                ...              ...            ...
# 17707          Upright             74.0         1195.0
# 17708          Upright             92.0       101511.0
# 17709          Upright             86.0         7146.0
# 17710          Upright             91.0        30193.0
# 17711          Upright             62.0         4469.0
#
#        tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 0                                 43                               73
# 1                                 44                              123
# 2                                  2                               16
# 3                                  6                               54
# 4                                  5                               24
# ...                              ...                              ...
# 17707                              2                                5
# 17708                             50                              285
# 17709                              0                                8
# 17710                              6                               22
# 17711                              0                                4
#
#        tomatometer_rotten_critics_count
# 0                                    76
# 1                                    19
# 2                                     8
# 3                                     0
# 4                                     3
# ...                                 ...
# 17707                                 4
# 17708                                 7
# 17709                                 2
# 17710                                 1
# 17711                                 4
#
# [17712 rows x 22 columns]

# %%
df = critics.merge(movies, how='inner', on=['rotten_tomatoes_link'])
df = df[['rotten_tomatoes_link', 'movie_title', 'critics_consensus', 'review_content', 'review_type']]
df
# Out:
#               rotten_tomatoes_link  \
# 0                        m/0814255
# 1                        m/0814255
# 2                        m/0814255
# 3                        m/0814255
# 4                        m/0814255
# ...                            ...
# 49995  m/1110242-collateral_damage
# 49996  m/1110242-collateral_damage
# 49997  m/1110242-collateral_damage
# 49998  m/1110242-collateral_damage
# 49999  m/1110242-collateral_damage
#
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1      Percy Jackson & the Olympians: The Lightning T...
# 2      Percy Jackson & the Olympians: The Lightning T...
# 3      Percy Jackson & the Olympians: The Lightning T...
# 4      Percy Jackson & the Olympians: The Lightning T...
# ...                                                  ...
# 49995                                  Collateral Damage
# 49996                                  Collateral Damage
# 49997                                  Collateral Damage
# 49998                                  Collateral Damage
# 49999                                  Collateral Damage
#
#                                        critics_consensus  \
# 0      Though it may seem like just another Harry Pot...
# 1      Though it may seem like just another Harry Pot...
# 2      Though it may seem like just another Harry Pot...
# 3      Though it may seem like just another Harry Pot...
# 4      Though it may seem like just another Harry Pot...
# ...                                                  ...
# 49995  Despite its timely subject matter, Collateral ...
# 49996  Despite its timely subject matter, Collateral ...
# 49997  Despite its timely subject matter, Collateral ...
# 49998  Despite its timely subject matter, Collateral ...
# 49999  Despite its timely subject matter, Collateral ...
#
#                                           review_content review_type
# 0      A fantasy adventure that fuses Greek mythology...       Fresh
# 1      Uma Thurman as Medusa, the gorgon with a coiff...       Fresh
# 2      With a top-notch cast and dazzling special eff...       Fresh
# 3      Whether audiences will get behind The Lightnin...       Fresh
# 4      What's really lacking in The Lightning Thief i...      Rotten
# ...                                                  ...         ...
# 49995  The smarter an Arnold Schwarzenegger movie tri...      Rotten
# 49996                                A relative letdown.      Rotten
# 49997  The movie straddles the fence between escapism...      Rotten
# 49998  Enough similarities to Gymkata and Howie Long'...      Rotten
# 49999  Age, and a steady diet of Republican conservat...      Rotten
#
# [50000 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# rotten_tomatoes_link       0
# movie_title                0
# critics_consensus       9796
# review_content          8805
# review_type                0
# dtype: int64

# %%
# Nulls can't be filled because there is no basleline review to fill them with
# Doesn't make sense to fill nulls with any content 
# because we are trying to use the text in review_content to predict tomatometer_status
df[df['review_content'].isnull()]
# Out:
#          rotten_tomatoes_link  \
# 80                  m/0814255
# 182                 m/0878835
# 283                 m/0878835
# 293                      m/10
# 294                      m/10
# ...                       ...
# 49936  m/1110048-pornographer
# 49937  m/1110048-pornographer
# 49981          m/1110236-wash
# 49986          m/1110236-wash
# 49987          m/1110236-wash
#
#                                              movie_title  \
# 80     Percy Jackson & the Olympians: The Lightning T...
# 182                                          Please Give
# 283                                          Please Give
# 293                                                   10
# 294                                                   10
# ...                                                  ...
# 49936                                   The Pornographer
# 49937                                   The Pornographer
# 49981                                           The Wash
# 49986                                           The Wash
# 49987                                           The Wash
#
#                                        critics_consensus review_content  \
# 80     Though it may seem like just another Harry Pot...            NaN
# 182    Nicole Holofcener's newest might seem slight i...            NaN
# 283    Nicole Holofcener's newest might seem slight i...            NaN
# 293    Blake Edwards' bawdy comedy may not score a pe...            NaN
# 294    Blake Edwards' bawdy comedy may not score a pe...            NaN
# ...                                                  ...            ...
# 49936                                                NaN            NaN
# 49937                                                NaN            NaN
# 49981  Sloppily-made, amateurish, and scarce on laugh...            NaN
# 49986  Sloppily-made, amateurish, and scarce on laugh...            NaN
# 49987  Sloppily-made, amateurish, and scarce on laugh...            NaN
#
#       review_type
# 80         Rotten
# 182        Rotten
# 283        Rotten
# 293         Fresh
# 294         Fresh
# ...           ...
# 49936      Rotten
# 49937       Fresh
# 49981      Rotten
# 49986      Rotten
# 49987      Rotten
#
# [8805 rows x 5 columns]

# %%
df[df['critics_consensus'].isnull()]
# Out:
#          rotten_tomatoes_link       movie_title critics_consensus  \
# 596     m/1000123-310_to_yuma      3:10 to Yuma               NaN
# 597     m/1000123-310_to_yuma      3:10 to Yuma               NaN
# 598     m/1000123-310_to_yuma      3:10 to Yuma               NaN
# 599     m/1000123-310_to_yuma      3:10 to Yuma               NaN
# 600     m/1000123-310_to_yuma      3:10 to Yuma               NaN
# ...                       ...               ...               ...
# 49933  m/1110048-pornographer  The Pornographer               NaN
# 49934  m/1110048-pornographer  The Pornographer               NaN
# 49935  m/1110048-pornographer  The Pornographer               NaN
# 49936  m/1110048-pornographer  The Pornographer               NaN
# 49937  m/1110048-pornographer  The Pornographer               NaN
#
#                                           review_content review_type
# 596    Despite an abundance of talk, this 1957 film i...       Fresh
# 597                                                  NaN       Fresh
# 598               Fine Daves, Ford collaborative western       Fresh
# 599    It's rather talky but always remains lively an...       Fresh
# 600    A taut Western (obviously inspired by High Noo...       Fresh
# ...                                                  ...         ...
# 49933                                                NaN      Rotten
# 49934                                                NaN      Rotten
# 49935  Not a soft-core porn flick with a mildly profe...       Fresh
# 49936                                                NaN      Rotten
# 49937                                                NaN       Fresh
#
# [9796 rows x 5 columns]

# %%
df = df.dropna(subset=['review_content', 'critics_consensus'])

# %%
df['review_content'].isnull().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 16

# %%
df[df.duplicated()]
# Out:
#                              rotten_tomatoes_link  \
# 7369                             m/10009212-ben_x
# 7757                           m/10009254-shutter
# 11168                         m/10010552-gigantic
# 13594                      m/10011582-TRON_legacy
# 14358                           m/10012014-babies
# 21509    m/1010678-invasion_of_the_body_snatchers
# 35577                           m/1069707-othello
# 42381                 m/1093611-anna_and_the_king
# 42572                         m/1093641-hurricane
# 42654                          m/1093655-diamonds
# 43503  m/1095351-1095351-what_planet_are_you_from
# 43548                 m/1095414-whatever_it_takes
# 43961                          m/1097046-dinosaur
# 44626                             m/1098038-shaft
# 44706                           m/1098149-patriot
# 47954                  m/1106020-someone_like_you
#
#                           movie_title  \
# 7369                            Ben X
# 7757                          Shutter
# 11168                        Gigantic
# 13594                     Tron Legacy
# 14358                          Babies
# 21509  Invasion of the Body Snatchers
# 35577                         Othello
# 42381               Anna and the King
# 42572                   The Hurricane
# 42654                        Diamonds
# 43503       What Planet Are You From?
# 43548               Whatever It Takes
# 43961                        Dinosaur
# 44626                           Shaft
# 44706                     The Patriot
# 47954                Someone Like You
#
#                                        critics_consensus  \
# 7369   Thoughtful and provocative Dutch film concerne...
# 7757   Being a remake of a Thai horror film instead o...
# 11168  This overly quirky, incessantly whimsical indi...
# 13594  Tron Legacy boasts dazzling visuals, but its h...
# 14358  Babies is a joyous celebration of humankind th...
# 21509  One of the best political allegories of the 19...
# 35577  Perhaps less than the sum of its parts, Othell...
# 42381  Beautiful cinematography can't prevent Anna an...
# 42572  Thanks in large part to one of Denzel Washingt...
# 42654  Kirk Douglas' flinty performance fails to over...
# 43503  Though What Planet Are You From? has some laug...
# 43548  Whatever It Takes is another run-of-the-mill t...
# 43961  While Dinosaur's plot is generic and dull, its...
# 44626  With a charismatic lead, this new Shaft knows ...
# 44706  The Patriot can be entertaining to watch, but ...
# 47954  A light and predictable, if somewhat shallow, ...
#
#                                           review_content review_type
# 7369   The best movie I've seen about teen angst sinc...       Fresh
# 7757   Workmanlike at best; derivative, predictable a...      Rotten
# 11168  Gigantic is the sort of kitchen sink movie man...      Rotten
# 13594  The film is visually dazzling, but the main pr...      Rotten
# 14358  Because of the inherent adorability of the fou...       Fresh
# 21509  The original version of the oft-filmed science...       Fresh
# 35577                        Fine Shakespeare adaptation       Fresh
# 42381  This version of Anna and the King plays it ent...      Rotten
# 42572  Denzel Washington gives yet another kick-ass p...       Fresh
# 42654                      A thoroughly enjoyable piece.       Fresh
# 43503   Find this funny? So do I. But not for two hours.      Rotten
# 43548  The unoriginal plot mixed with the apparent in...      Rotten
# 43961                                   Plot? What plot?      Rotten
# 44626  Excellent a film as it may be, don't expect Sh...       Fresh
# 44706  The Patriot comes across strong with some exce...       Fresh
# 47954  A sassy, romantic comedy about the battle of t...       Fresh

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#               rotten_tomatoes_link  \
# 0                        m/0814255
# 1                        m/0814255
# 2                        m/0814255
# 3                        m/0814255
# 4                        m/0814255
# ...                            ...
# 49995  m/1110242-collateral_damage
# 49996  m/1110242-collateral_damage
# 49997  m/1110242-collateral_damage
# 49998  m/1110242-collateral_damage
# 49999  m/1110242-collateral_damage
#
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1      Percy Jackson & the Olympians: The Lightning T...
# 2      Percy Jackson & the Olympians: The Lightning T...
# 3      Percy Jackson & the Olympians: The Lightning T...
# 4      Percy Jackson & the Olympians: The Lightning T...
# ...                                                  ...
# 49995                                  Collateral Damage
# 49996                                  Collateral Damage
# 49997                                  Collateral Damage
# 49998                                  Collateral Damage
# 49999                                  Collateral Damage
#
#                                        critics_consensus  \
# 0      Though it may seem like just another Harry Pot...
# 1      Though it may seem like just another Harry Pot...
# 2      Though it may seem like just another Harry Pot...
# 3      Though it may seem like just another Harry Pot...
# 4      Though it may seem like just another Harry Pot...
# ...                                                  ...
# 49995  Despite its timely subject matter, Collateral ...
# 49996  Despite its timely subject matter, Collateral ...
# 49997  Despite its timely subject matter, Collateral ...
# 49998  Despite its timely subject matter, Collateral ...
# 49999  Despite its timely subject matter, Collateral ...
#
#                                           review_content review_type
# 0      A fantasy adventure that fuses Greek mythology...       Fresh
# 1      Uma Thurman as Medusa, the gorgon with a coiff...       Fresh
# 2      With a top-notch cast and dazzling special eff...       Fresh
# 3      Whether audiences will get behind The Lightnin...       Fresh
# 4      What's really lacking in The Lightning Thief i...      Rotten
# ...                                                  ...         ...
# 49995  The smarter an Arnold Schwarzenegger movie tri...      Rotten
# 49996                                A relative letdown.      Rotten
# 49997  The movie straddles the fence between escapism...      Rotten
# 49998  Enough similarities to Gymkata and Howie Long'...      Rotten
# 49999  Age, and a steady diet of Republican conservat...      Rotten
#
# [34496 rows x 5 columns]

# %%
X = df.drop(columns=["review_type", "movie_title", "rotten_tomatoes_link"])
y = df["review_type"]

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.20, 
                                                    random_state=42)

# %%
df['review_type'].value_counts()
# Out:
# Fresh     21048
# Rotten    13448
# Name: review_type, dtype: int64

# %%
# Check out the y_train class balance 
y_train.value_counts()
# Out:
# Fresh     16874
# Rotten    10722
# Name: review_type, dtype: int64

# %%
# Plot the class the balance on a histogram
sns.histplot(data=y_train.sort_values(), 
             discrete=False)

plt.title("Class Balance Comparision")
plt.xlabel("Review Type")
plt.ylabel("Number of Samples");

# %%
# Check out the y_test class balance 
y_test.value_counts()
# Out:
# Fresh     4174
# Rotten    2726
# Name: review_type, dtype: int64

# %%
np.unique(y_test,
          return_counts=True)
# Out:
# (array(['Fresh', 'Rotten'], dtype=object), array([4174, 2726], dtype=int64))

# %%
# Plot the class the balance on a histogram

sns.histplot(data=y_test.sort_values(), 
             discrete=False)

plt.title("Class Balance Comparision")
plt.xlabel("Review Type")
plt.ylabel("Number of Samples");

# %%
label_encoder = preprocessing.LabelEncoder()

y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

print(y_train), print(y_test)
# Out:
# [0 0 0 ... 1 0 1]
# [1 0 0 ... 1 0 0]
# (None, None)

# %%
from PIL import Image
from wordcloud import WordCloud #library that allows word cloud to be generated

def generate_word_cloud(dataframe_df,column_name,img_file=None,background_color="black",max_words=2000):
    """ This function generates word cloud
    
    Args:
        dataframe: the datafram object which contains column whose word cloud is to be generated
        column_name: the name of the column in dataframw whose cloud is to be generated
        
    Returns:
        None
    """
    #convert the column specified by column_name in dataset_df(dataframe) to list
    sentences_list = dataframe_df[column_name].tolist()
    
    #convert a list to sentence
    #sentences_single_string = " ".join(sentences_list)
    sentences_single_string = " ".join(map(str,sentences_list))
    
    #plot word cloud
    plt.figure(figsize=(15,15))
    
    img_mask = None
    
    if img_file != None:
        img_mask = np.array(Image.open(img_file))

    wc = WordCloud(mask=img_mask,
                   max_words=max_words,
                   background_color=background_color)        
        
    plt.imshow(wc.generate(sentences_single_string),interpolation="bilinear")
    plt.title("Word Cloud For " +  column_name)
    plt.show()

# %%
import time
tic= time.time()
generate_word_cloud(df,
                    "review_content",
                    background_color="black")
toc = time.time()
diff = 1000*(toc - tic)
print("Total Time Taken: " + str(diff) + " ms")
# Out:
# Total Time Taken: 2965.1176929473877 ms

# %%
# Create an intance of the RegexpTokenizer with the variable name `tokenizer`
# The regex pattern should select all words with three or more characters
pattern = r"(?u)\w{3,}"
tokenizer = RegexpTokenizer(pattern)

# Create a list of stopwords in English
stopwords_list = stopwords.words('english')

# Create an instance of nltk's PorterStemmer with the variable name `stemmer`
lemmatizer = WordNetLemmatizer()

# %%
def preprocess_text(text, tokenizer, stopwords_list, lemmatizer):
    # Standardize case (lowercase the text)
    lowered = text.lower()
    
    # Tokenize text using `tokenizer`
    tokens = tokenizer.tokenize(lowered)
    
    # Remove stopwords using `stopwords_list`
    stopped_tokens = [word for word in tokens if word not in stopwords_list]
    
    # Stem the tokenized text using `stemmer`
    lemmas = [lemmatizer.lemmatize(token) for token in stopped_tokens]

    # Return the preprocessed text
    return lemmas

# %%
# View a record without process_string() applied
X_train["review_content"].iloc[4]
# Out:
# 'Light on originality and low on suspense.'

# %%
preprocess_text(X_train["review_content"].iloc[4], tokenizer, stopwords_list, lemmatizer)
# Out:
# ['light', 'originality', 'low', 'suspense']

# %%
df['review_content'] = df['review_content'].apply(lambda x: preprocess_text(x, tokenizer, stopwords_list, lemmatizer))

# %%
X_train['review_content'] = X_train['review_content'].apply(lambda x: preprocess_text(x, tokenizer, stopwords_list, lemmatizer))

# %%
X_test['review_content'] = X_test['review_content'].apply(lambda x: preprocess_text(x, tokenizer, stopwords_list, lemmatizer))

# %%
tic = time.time()
generate_word_cloud(df,
                    "review_content",
                    background_color="black")
toc = time.time()
diff = toc - tic
print("Total Time Taken: " + str(diff) + " ms")
# Out:
# Total Time Taken: 3.8461406230926514 ms

# %%
# Save file to csv
df.to_csv("./data/df.csv")
X_train.to_csv("./data/X_train.csv")
X_test.to_csv("./data/X_test.csv")

# %%
df = pd.read_csv("./data/df.csv")
X_train = pd.read_csv("./data/X_train.csv")
X_test = pd.read_csv("./data/X_test.csv")

# %%
vectorizer = CountVectorizer()

labels = label_encoder.fit_transform(df["review_type"])
features = vectorizer.fit_transform(df["review_content"].tolist())
matrix = pd.DataFrame.sparse.from_spmatrix(data=features, columns=vectorizer.get_feature_names())

# %%
def plot_top_words(document_term_df,upper_threshold=10000,lower_threshold=10,count=20):
    
    #for time purposes
    tic = time.time()
    
    top_word_freq = {}
    #build frequency dictionary
    for col in document_term_df.columns:
        
        col_count = document_term_df[col].to_numpy().max()
        
        if lower_threshold < col_count < upper_threshold:
            top_word_freq[col] = col_count
            
        if len(top_word_freq) > count:
            break

    #print thresholds
    print("Upper Limit: " + str(upper_threshold))
    print("Lower Limit: " + str(lower_threshold))
    print("Requested Count: " + str(count))
    
    plt.figure(figsize=(20,10))
    
    y_vals = [top_word_freq[word] for word in top_word_freq.keys()]
    
    anotates = list(top_word_freq.keys())
    
    x_vals = [i for i in range(0,len(y_vals))]
    
    plt.scatter(x_vals,y_vals)

    plt.title("Top Word Counts")
    plt.xlabel("Top Words")
    plt.ylabel("Word Frequency")
    
    for y,a,x in zip(y_vals,anotates,x_vals):
        plt.annotate(a, #anotate
                     (x,y), #for this data point 
                    textcoords="offset points", #how to position text
                    xytext=(0,10), #distance from text to points (x,y)
                    ha="center") #horizontal alignment can beleft, right or center 
    
    #for time purposes
    toc = time.time()
    tictoc = (toc-tic)*1000
    print("Time Taken: " + str(tictoc) + " ms")

# %%
plot_top_words(matrix,
               upper_threshold=10,
               lower_threshold=3,
               count=25)
# Out:
# Upper Limit: 10
# Lower Limit: 3
# Requested Count: 25
# Time Taken: 1376.2147426605225 ms

# %%
plot_top_words(matrix[labels == 1],
               upper_threshold=10,
               lower_threshold=2,
               count=25)
# Out:
# Upper Limit: 10
# Lower Limit: 2
# Requested Count: 25
# Time Taken: 322.12257385253906 ms

# %%
plot_top_words(matrix[labels == 0],
               upper_threshold=10,
               lower_threshold=2,
               count=25)
# Out:
# Upper Limit: 10
# Lower Limit: 2
# Requested Count: 25
# Time Taken: 497.9891777038574 ms

# %%
tf_idf = TfidfVectorizer()


X_train = tf_idf.fit_transform(X_train["review_content"].tolist())
X_test = tf_idf.transform(X_test["review_content"].tolist())

print(X_train.shape, X_test.shape)
# Out:
# (32940, 28157) (8236, 28157)

# %%
# Create Dummy/Baseliner
estimator = DummyClassifier(strategy='most_frequent')
estimator.fit(X_train, y_train)

# Get predictions with dummy model
y_pred = estimator.predict(X_test)


# Set figsize and font scale
sns.set(rc={'figure.figsize':(9, 4)})
sns.set(font_scale=1)

# Set diply labesl for confusion matrix
display_labels = ['Fresh', 'Rotten']

# Plot a confusion matrix on the test data
plot_confusion_matrix(estimator=estimator,
                      X=X_test,
                      y_true=y_test,
                      display_labels=display_labels)

# Save confusion matrix as png and place it in the images folder
plt.savefig('images/Confusion_Matrix_Dummy');

target_names = ['Fresh', 'Rotten']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#        Fresh       0.60      1.00      0.75      4977
#       Rotten       0.00      0.00      0.00      3259
#
#     accuracy                           0.60      8236
#    macro avg       0.30      0.50      0.38      8236
# weighted avg       0.37      0.60      0.46      8236

# %%
pipe = Pipeline(steps=[
    ('estimator', LogisticRegression(random_state=42))
])



param_grid = {}
param_grid['estimator__C'] = [100, 10, 1.0, 0.1, 0.01]
param_grid['estimator__solver'] = ['newton-cg', 'lbfgs', 'liblinear']
param_grid['estimator__penalty'] = ['l2']



grid_search = GridSearchCV(estimator=pipe, 
                           param_grid=param_grid, 
                           cv=RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42), 
                           return_train_score=True, 
                           scoring='accuracy', 
                           n_jobs=-1,
                           verbose=2)



# Fit models run gridsearch
grid_search.fit(X_train, y_train)

# Mean training score
grid_train_score = np.mean(grid_search.cv_results_['mean_train_score'])

# Mean test score
grid_test_score = grid_search.score(X_test, y_test)

best_grid = grid_search.best_estimator_
best_grid.fit(X_train, y_train)
y_pred = best_grid.predict(X_test)



print(f"Mean Training Score: {grid_train_score:.2%}\n")
print(f"Mean Test Score: {grid_test_score:.2%}\n")

print(f"Optimal Parameters: {grid_search.best_params_}\n")
print(f"Testing Accuracy: {grid_search.best_score_:.2%}\n")

# Label 0, 1, 2 in classification reports
target_names = ['Fresh', 'Rotten']
print(classification_report(y_test, y_pred, target_names=target_names))



# Set figsize and font scale
sns.set(rc={'figure.figsize':(9, 4)})
sns.set(font_scale=1)

# Set diply labesl for confusion matrix
display_labels = ['Fresh', 'Rotten']

# Plot a confusion matrix on the test data
plot_confusion_matrix(estimator=estimator,
                      X=X_test,
                      y_true=y_test,
                      display_labels=display_labels)

# Save confusion matrix as png and place it in the images folder
plt.savefig('images/Confusion_Matrix_LogReg');
# Out:
# Fitting 30 folds for each of 15 candidates, totalling 450 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:   44.3s
# [Parallel(n_jobs=-1)]: Done 450 out of 450 | elapsed:   47.4s finished
# Mean Training Score: 82.11%
#
# Mean Test Score: 78.25%
#
# Optimal Parameters: {'estimator__C': 1.0, 'estimator__penalty': 'l2', 'estimator__solver': 'liblinear'}
#
# Testing Accuracy: 77.84%
#
#               precision    recall  f1-score   support
#
#        Fresh       0.79      0.88      0.83      4977
#       Rotten       0.78      0.63      0.70      3259
#
#     accuracy                           0.78      8236
#    macro avg       0.78      0.76      0.76      8236
# weighted avg       0.78      0.78      0.78      8236
